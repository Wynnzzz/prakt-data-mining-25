# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
df_1=pd.read_excel('Data/sales_dataset.xlsx')
df_1
# Out:
#        Unnamed: 0 Unnamed: 1       Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0             NaN  Paid Date     Order Number  First Name  Last Name
# 1             NaN   20170724  201707240088517     elvride      aries
# 2             NaN   20170701  201707018889790       BASIR      Ninuk
# 3             NaN   20170707  201707079264675       Citra       Ardi
# 4             NaN   20170720  201707209945714        Dian    Renaldi
# ...           ...        ...              ...         ...        ...
# 11996         NaN   20171201  201712012704898      Fitrah       gina
# 11997         NaN   20171203  201712032723513     Djebeng     Shinta
# 11998         NaN   20171204  201712042740205        Amik       Elan
# 11999         NaN   20171207  201712072778621        Anna       asih
# 12000         NaN   20171205  201712052746101      nidyah        ayi
#
#              Unnamed: 5                                         Unnamed: 6  \
# ...

# %%
df_1=pd.read_excel('Data/sales_dataset.xlsx',sheet_name='Paid-Transaction',skiprows=[0],usecols=[x for x in range(1,12)])
df_1
# Out:
#        Paid Date     Order Number First Name Last Name     Meta Category  \
# 0       20170724  201707240088517    elvride     aries      Babies/ Kids
# 1       20170701  201707018889790      BASIR     Ninuk   Service/ Mokado
# 2       20170707  201707079264675      Citra      Ardi   Service/ Mokado
# 3       20170720  201707209945714       Dian   Renaldi           Fashion
# 4       20170722  201707220002354      rizal     Tamba  Gadget/ Komputer
# ...          ...              ...        ...       ...               ...
# 11995   20171201  201712012704898     Fitrah      gina   Service/ Mokado
# 11996   20171203  201712032723513    Djebeng    Shinta   Service/ Mokado
# 11997   20171204  201712042740205       Amik      Elan        Home/ Food
# 11998   20171207  201712072778621       Anna      asih  Gadget/ Komputer
# 11999   20171205  201712052746101     nidyah       ayi   Service/ Mokado
#
#                                             Product Name  Transaction Amount  \
# ...

# %%
df_1=pd.read_excel('https://docs.google.com/spreadsheets/d/1rRw1XlITsRME-AHXggmS14BjrMvMqHqBHtmDS7XQY3M/export?format=xlsx',sheet_name='Paid-Transaction',skiprows=[0],usecols=[x for x in range(1,12)])
df_1
# Out:
#        Paid Date     Order Number First Name Last Name     Meta Category  \
# 0       20170724  201707240088517    elvride     aries      Babies/ Kids
# 1       20170701  201707018889790      BASIR     Ninuk   Service/ Mokado
# 2       20170707  201707079264675      Citra      Ardi   Service/ Mokado
# 3       20170720  201707209945714       Dian   Renaldi           Fashion
# 4       20170722  201707220002354      rizal     Tamba  Gadget/ Komputer
# ...          ...              ...        ...       ...               ...
# 11995   20171201  201712012704898     Fitrah      gina   Service/ Mokado
# 11996   20171203  201712032723513    Djebeng    Shinta   Service/ Mokado
# 11997   20171204  201712042740205       Amik      Elan        Home/ Food
# 11998   20171207  201712072778621       Anna      asih  Gadget/ Komputer
# 11999   20171205  201712052746101     nidyah       ayi   Service/ Mokado
#
#                                             Product Name  Transaction Amount  \
# ...

# %%
df_2=pd.read_csv('Data/ecommerce_dataset.csv')
df_2
# Out:
#             Order ID  Order Date   Ship Date  Aging       Ship Mode  \
# 0          AU-2015-1  2015-11-09  2015-11-17    8.0     First Class
# 1          AU-2015-2  2015-06-30  2015-07-02    2.0     First Class
# 2          AU-2015-3  2015-12-05  2015-12-13    8.0     First Class
# 3          AU-2015-4  2015-05-09  2015-05-16    7.0     First Class
# 4          AU-2015-5  2015-07-09  2015-07-18    9.0     First Class
# ...              ...         ...         ...    ...             ...
# 51298  FA-2015-30775  2016-01-02  2016-01-06    5.0  Standard Class
# 51299  FA-2015-30775  2016-01-02  2016-01-06    5.0  Standard Class
# 51300  FA-2015-30775  2016-01-02  2016-01-06    5.0  Standard Class
# 51301  FA-2015-30775  2016-01-02  2016-01-06    5.0  Standard Class
# 51302  FA-2015-30775  2016-01-02  2016-01-06    5.0  Standard Class
#
#          Product Category            Product    Sales Quantity Discount  ...  \
# ...

# %% [markdown]
# ##### Data Analyzing

# %%
df_1.head()
# Out:
#    Paid Date     Order Number First Name Last Name     Meta Category  \
# 0   20170724  201707240088517    elvride     aries      Babies/ Kids
# 1   20170701  201707018889790      BASIR     Ninuk   Service/ Mokado
# 2   20170707  201707079264675      Citra      Ardi   Service/ Mokado
# 3   20170720  201707209945714       Dian   Renaldi           Fashion
# 4   20170722  201707220002354      rizal     Tamba  Gadget/ Komputer
#
#                                         Product Name  Transaction Amount  \
# 0  Pineapple Hat Anak Ala Korea - 6M - 4Y - Unise...              300000
# 1                                 Pulsa BOLT 150.000              287800
# 2                          XTRA Combo 12X 6GB, 12bln               35000
# 3  Square Foldable Travel Bag / Tas Koper Luggage...               85000
# 4                         Samsung Galaxy Note 5 Gold               81000
#
#    Seller Discount  Sales Discount  Delivery Fee  Other Discount
# ...

# %%
df_1.tail()
# Out:
#        Paid Date     Order Number First Name Last Name     Meta Category  \
# 11995   20171201  201712012704898     Fitrah      gina   Service/ Mokado
# 11996   20171203  201712032723513    Djebeng    Shinta   Service/ Mokado
# 11997   20171204  201712042740205       Amik      Elan        Home/ Food
# 11998   20171207  201712072778621       Anna      asih  Gadget/ Komputer
# 11999   20171205  201712052746101     nidyah       ayi   Service/ Mokado
#
#                                             Product Name  Transaction Amount  \
# 11995                              Xtra Combo 12GB, 30hr              333000
# 11996                              Xtra Combo 12GB, 30hr              280000
# 11997  Kreta - Kripik Tempe Indonesia - Rasa Jomblo d...              150000
# 11998  Samsung Galaxy J5 Pro Garansi Resmi Special Price              475000
# 11999  [SERBU 11.12] Share Tea Cocoa Rocksalt & Chees...              475000
#
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Paid Date           12000 non-null  int64
#  1   Order Number        12000 non-null  int64
#  2   First Name          11996 non-null  object
#  3   Last Name           11996 non-null  object
#  4   Meta Category       12000 non-null  object
#  5   Product Name        12000 non-null  object
#  6   Transaction Amount  12000 non-null  int64
#  7   Seller Discount     12000 non-null  int64
#  8   Sales Discount      12000 non-null  float64
#  9   Delivery Fee        12000 non-null  int64
#  10  Other Discount      12000 non-null  float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 1.0+ MB

# %%
df_1.describe()
# Out:
#           Paid Date  Order Number  Transaction Amount  Seller Discount  \
# count  1.200000e+04  1.200000e+04        1.200000e+04     1.200000e+04
# mean   2.017096e+07  2.017096e+14        2.671306e+05     4.262532e+04
# std    1.690360e+02  1.694340e+09        1.051868e+06     1.289358e+05
# min    2.017070e+07  2.017062e+14        1.000000e+02     0.000000e+00
# 25%    2.017081e+07  2.017081e+14        5.000000e+04     0.000000e+00
# 50%    2.017097e+07  2.017093e+14        8.900000e+04     0.000000e+00
# 75%    2.017111e+07  2.017111e+14        1.600000e+05     4.000000e+04
# max    2.017121e+07  2.017121e+14        3.051600e+07     4.252500e+06
#
#        Sales Discount  Delivery Fee  Other Discount
# count    1.200000e+04  12000.000000    12000.000000
# mean     1.003629e+04   1710.883333      708.973582
# std      6.238404e+04   4056.440079    11005.441981
# min      0.000000e+00      0.000000        0.000000
# 25%      0.000000e+00      0.000000        0.000000
# ...

# %%
df_1.sort_values('Transaction Amount',ascending=False)
# Out:
#       Paid Date     Order Number First Name  Last Name     Meta Category  \
# 1098   20170704  201707049121938      jelin     Edward        Home/ Food
# 9031   20171115  201711152495803     yunita       josh   Service/ Mokado
# 5056   20170911  201709111494006      Linda  herlijoso   Service/ Mokado
# 1516   20170711  201707119502615     Nining     martin  Gadget/ Komputer
# 3206   20170828  201708281180810     PETRUS      sinda   Service/ Mokado
# ...         ...              ...        ...        ...               ...
# 1032   20170710  201707109438476        Mei       Dini   Service/ Mokado
# 1029   20170703  201707039069350       Iman      Putra   Service/ Mokado
# 2928   20170814  201708110765560      Marwa   platform        Home/ Food
# 1040   20170728  201707280281816     Hience       Dini   Service/ Mokado
# 1025   20170726  201707219977038       enny      Pande           Fashion
#
#                                            Product Name  Transaction Amount  \
# ...

# %%
df_arr=pd.DataFrame([1,2,3,4,5],index=[100,29,234,1,150], columns=['A'])
df_arr.sort_index()
# Out:
#      A
# 1    4
# 29   2
# 100  1
# 150  5
# 234  3

# %% [markdown]
# ##### Filtering Data Frame

# %%
df_1[['First Name','Last Name']]
# Out:
#       First Name Last Name
# 0        elvride     aries
# 1          BASIR     Ninuk
# 2          Citra      Ardi
# 3           Dian   Renaldi
# 4          rizal     Tamba
# ...          ...       ...
# 11995     Fitrah      gina
# 11996    Djebeng    Shinta
# 11997       Amik      Elan
# 11998       Anna      asih
# 11999     nidyah       ayi
#
# [12000 rows x 2 columns]

# %%
df_1.filter(items=['First Name', 'Last Name'])
# Out:
#       First Name Last Name
# 0        elvride     aries
# 1          BASIR     Ninuk
# 2          Citra      Ardi
# 3           Dian   Renaldi
# 4          rizal     Tamba
# ...          ...       ...
# 11995     Fitrah      gina
# 11996    Djebeng    Shinta
# 11997       Amik      Elan
# 11998       Anna      asih
# 11999     nidyah       ayi
#
# [12000 rows x 2 columns]

# %% [markdown]
# ###### Metode loc dan iloc

# %%
df_1.loc[(df_1['Meta Category']=='Home/ Food')]
# Out:
#        Paid Date     Order Number First Name  Last Name Meta Category  \
# 19      20170721  201707219967054      hardi     yovial    Home/ Food
# 41      20170715  201707149673613         rr       Vita    Home/ Food
# 54      20170728  201707280270645      Herli    Maryana    Home/ Food
# 68      20170712  201707129559653  Anastasia  taufikady    Home/ Food
# 74      20170708  201707079309786      LINDA       Giok    Home/ Food
# ...          ...              ...        ...        ...           ...
# 11945   20171204  201712032723789     Jaohan       Leli    Home/ Food
# 11949   20171206  201712052758963      Lusia      Anggi    Home/ Food
# 11984   20171206  201712042740007       Made        Dwi    Home/ Food
# 11993   20171202  201711302697149     Hendri      Shasa    Home/ Food
# 11997   20171204  201712042740205       Amik       Elan    Home/ Food
#
#                                             Product Name  Transaction Amount  \
# ...

# %%
df_1.iloc[[0,3]]
# Out:
#    Paid Date     Order Number First Name Last Name Meta Category  \
# 0   20170724  201707240088517    elvride     aries  Babies/ Kids
# 3   20170720  201707209945714       Dian   Renaldi       Fashion
#
#                                         Product Name  Transaction Amount  \
# 0  Pineapple Hat Anak Ala Korea - 6M - 4Y - Unise...              300000
# 3  Square Foldable Travel Bag / Tas Koper Luggage...               85000
#
#    Seller Discount  Sales Discount  Delivery Fee  Other Discount
# 0           153000         10200.0          9000             0.0
# 3                0          5900.0             0             0.0

# %% [markdown]
# ##### Menambahkan Kolom Baru

# %%
df_1_copy=df_1.copy()

# %%
nama=(df_1['First Name']+" "+df_1['Last Name']).str.title()
nama
# Out:
# 0         Elvride Aries
# 1           Basir Ninuk
# 2            Citra Ardi
# 3          Dian Renaldi
# 4           Rizal Tamba
#               ...
# 11995       Fitrah Gina
# 11996    Djebeng Shinta
# 11997         Amik Elan
# 11998         Anna Asih
# 11999        Nidyah Ayi
# Length: 12000, dtype: object

# %%
df_1_copy['Full Name']=nama

# %%
df_1_copy
# Out:
#        Paid Date     Order Number First Name Last Name     Meta Category  \
# 0       20170724  201707240088517    elvride     aries      Babies/ Kids
# 1       20170701  201707018889790      BASIR     Ninuk   Service/ Mokado
# 2       20170707  201707079264675      Citra      Ardi   Service/ Mokado
# 3       20170720  201707209945714       Dian   Renaldi           Fashion
# 4       20170722  201707220002354      rizal     Tamba  Gadget/ Komputer
# ...          ...              ...        ...       ...               ...
# 11995   20171201  201712012704898     Fitrah      gina   Service/ Mokado
# 11996   20171203  201712032723513    Djebeng    Shinta   Service/ Mokado
# 11997   20171204  201712042740205       Amik      Elan        Home/ Food
# 11998   20171207  201712072778621       Anna      asih  Gadget/ Komputer
# 11999   20171205  201712052746101     nidyah       ayi   Service/ Mokado
#
#                                             Product Name  Transaction Amount  \
# ...

# %%
df_1.insert(4,'Full Name',nama)

# %%
df_1.head()
# Out:
#    Paid Date     Order Number First Name Last Name      Full Name  \
# 0   20170724  201707240088517    elvride     aries  Elvride Aries
# 1   20170701  201707018889790      BASIR     Ninuk    Basir Ninuk
# 2   20170707  201707079264675      Citra      Ardi     Citra Ardi
# 3   20170720  201707209945714       Dian   Renaldi   Dian Renaldi
# 4   20170722  201707220002354      rizal     Tamba    Rizal Tamba
#
#       Meta Category                                       Product Name  \
# 0      Babies/ Kids  Pineapple Hat Anak Ala Korea - 6M - 4Y - Unise...
# 1   Service/ Mokado                                 Pulsa BOLT 150.000
# 2   Service/ Mokado                          XTRA Combo 12X 6GB, 12bln
# 3           Fashion  Square Foldable Travel Bag / Tas Koper Luggage...
# 4  Gadget/ Komputer                         Samsung Galaxy Note 5 Gold
#
#    Transaction Amount  Seller Discount  Sales Discount  Delivery Fee  \
# ...

# %% [markdown]
# ##### Grouping & Aggregating Data Frame

# %% [markdown]
# ###### Grouping adalah suatu teknik memilah data pada Data Frame berdasarkan kriteria tertentu. Grouping memungkinkan untuk melakukan komputasi atau operasi tertentu kepada data-data spesifik tersebut.

# %%
df_1.groupby('Meta Category')['Transaction Amount'].sum()
# Out:
# Meta Category
# Babies/ Kids               131241200
# Beauty/ Health             260650800
# Elektronik                  31327900
# Fashion                    497267800
# Gadget/ Komputer           290581200
# Home/ Food                 370359100
# Service/ Mokado           1553091800
# Sports/ Hobi/ Otomotif      71047100
# Name: Transaction Amount, dtype: int64

# %% [markdown]
# ###### Aggregation digunakan untuk melakukan komputasi statistik terhadap data-data yang telah dikelompokkan

# %% [markdown]
# ###### Operasi yang dapat diterapkan yaitu sum, min, max, mean, size, describe, first, last, count, std, var, sem

# %%
df_1.groupby('Product Name').agg(rata_rata=('Transaction Amount', 'mean'),
                                 maksimum=('Transaction Amount', 'max'),
                                 minimum=('Transaction Amount', 'min'))
# Out:
#                                                         rata_rata  maksimum  \
# Product Name
# "2 PCS" Baju Anak Perempuan Motif Size L ( 5-7 ...  109000.000000    109000
# "Premium Dates" Kurma Lulu_1000 gram                110000.000000    110000
# #Action Camera Tripod Mini YUNTENG YT-228 + Hol...  750000.000000    750000
# #Casing & Cover cocose dragon redmi note 4X coc...   31200.000000     31200
# #Celana Renang Pria Celana renang SPEEDO dewasa     107000.000000    107000
# ...                                                           ...       ...
# ★Micro SD★ V-GEN│VGEN│8 GB│Class 6 no Adapter│      175000.000000    175000
# 💗 BLOUSE TRENDY / PASTEL BLOUSE/ BLOUSE WANITA 💗     51800.000000     51800
# 💗HOT💗 Tavia Legging Jumbo size and Standard siz...   53650.000000     86400
# 💙HOT💙Gamis Casual/ Gamis Murah/ Gamis Etnik          76800.000000     76800
# 🔥NEW🔥 Blouse Motif ceria dan elegant XL XXL         203433.333333    399000
#
# ...

# %% [markdown]
# ##### Data Merge

# %% [markdown]
# <img src="Img/types-of-joins.png">

# %%
employees = pd.DataFrame({'id':[1,2,3,4],'name':['Johana','Mike','Patricia','James']})
employees
# Out:
#    id      name
# 0   1    Johana
# 1   2      Mike
# 2   3  Patricia
# 3   4     James

# %%
salary = pd.DataFrame({'id':[1,2,3,5],'salary':[120000,100000,130000,90000]})
salary
# Out:
#    id  salary
# 0   1  120000
# 1   2  100000
# 2   3  130000
# 3   5   90000

# %%
employees_with_salary = employees.merge(salary,
                                        left_on="id",
                                        right_on="id",
                                        how='inner')  # default
employees_with_salary
# Out:
#    id      name  salary
# 0   1    Johana  120000
# 1   2      Mike  100000
# 2   3  Patricia  130000

# %%
employees_with_salary2 = employees.merge(salary,
                                        left_on="id",
                                        right_on="id")
employees_with_salary2
# Out:
#    id      name  salary
# 0   1    Johana  120000
# 1   2      Mike  100000
# 2   3  Patricia  130000

# %%
employees_with_salary_outer = employees.merge(salary, 
                                              left_on='id',
                                              right_on='id', 
                                              how='outer')
employees_with_salary_outer
# Out:
#    id      name    salary
# 0   1    Johana  120000.0
# 1   2      Mike  100000.0
# 2   3  Patricia  130000.0
# 3   4     James       NaN
# 4   5       NaN   90000.0

# %%
employees_with_salary_left = employees.merge(salary,
                                             left_on='id',
                                             right_on='id',
                                             how='left')
employees_with_salary_left
# Out:
#    id      name    salary
# 0   1    Johana  120000.0
# 1   2      Mike  100000.0
# 2   3  Patricia  130000.0
# 3   4     James       NaN

# %%
employees_with_salary_right = employees.merge(salary,
                                              left_on='id',
                                              right_on='id',
                                              how='right')
employees_with_salary_right
# Out:
#    id      name  salary
# 0   1    Johana  120000
# 1   2      Mike  100000
# 2   3  Patricia  130000
# 3   5       NaN   90000

# %%
employees.merge(salary, on="id")
# Out:
#    id      name  salary
# 0   1    Johana  120000
# 1   2      Mike  100000
# 2   3  Patricia  130000
